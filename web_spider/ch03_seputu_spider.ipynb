# %% [markdown]
# # 盗墓笔记小说爬虫
#
# ## 1. 爬取页面

# %%
import requests
import books_bs_parser as bp

# %%
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6)\
AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'

# %%
user_agent
# Out:
# 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'

# %%
headers = {'User-Agent': user_agent}
r = requests.get('http://seputu.com/', headers=headers)

# %%
r.encoding
# Out:
# 'UTF-8'

# %% [markdown]
# ## 2. 解析并存储页面

# %% [markdown]
# ### 使用BeautifulSoup解析页面以及用JSON存储数据

# %%
# !cat books_bs_parser.py
# Out:
# '''
# 基于BeautifulSoup和JSON的HTML静态页面解析和数据存储模块
# '''
# from bs4 import BeautifulSoup
# import json
#
# def parse_books(html_text):
#     '''从HTML文本中解析出所有图书列表'''
#     soup = BeautifulSoup(html_text, 'lxml')
#     books = []
#     book_divs = soup.find_all('div', class_="mulu")
#
#     for book_div in book_divs:
#         h2 = book_div.find('h2')
#         if h2 != None:
#             book_title = h2.text # 获取标题
#             links = book_div.find_all('a')
#             chapters = parse_chapters(links)
#             books.append({'book_title': book_title, 'chapters': chapters})
#
#         def parse_chapters(links):
#             chapters = []
#             for link in links:
#                 href = link.get('href')
#                 title = link.get('title')
#                 chapters.append({'href':href, 'title':title})
#             return chapters
#
#     return books
#
# def save_books_json(filename, books):
#     '''将图书列表保存到JSON文件中'''
#     with open(filename, 'w') as f:
#             json.dump(books, fp = f, indent = 4)

# %%
# 解析图书
books = bp.parse_books(r.text)
help(bp)
# Out:
# Help on module books_bs_parser:
#
# NAME
#     books_bs_parser - 基于BeautifulSoup和JSON的HTML静态页面解析和数据存储模块
#
# FUNCTIONS
#     parse_books(html_text)
#         从HTML文本中解析出所有图书列表
#
#     save_books(filename, books)
#         将图书列表保存到JSON文件中
#
# FILE
#     /Users/xiaobai/Workspace/labs/python-samples/web_spider/books_bs_parser.py

# %%
# 保存图书为JSON文件
bp.save_books('books.json',books)

# %% [markdown]
# ### 使用LXML解析页面以及用CSV存储数据

# %%
import books_xp_parser as bxp

# %%
# !cat books_xp_parser.py
# Out:
# '''
# 基于lxml和CSV的HTML静态页面解析和数据存储模块
# '''
# from lxml import etree
# import re, csv
#
# def parse_books(html_text):
#     '''
#     从HTML文本中解析出所有图书列表
#     '''
#     tree = etree.HTML(html_text)
#     book_divs = tree.xpath('.//div[@class="mulu"]')
#     pattern = re.compile(r'\s*\[(.*)\]\s+(.*)')
#     rows = []
#
#     def parse_row(book_title, links):
#         href = link.xpath('./@href')[0]
#         title = link.xpath('./@title')[0]
#         match = re.search(pattern, title)
#         if match != None:
#             date = match.group(1)
#             title = match.group(2)
#             row = (book_title, title, href, date)
#             return row
#         else:
#             return None
#
#     for book_div in book_divs:
#         div_h2 = book_div.xpath('./div/center/h2/text()')
#         if (len(div_h2) > 0):
#             book_title = div_h2[0]
#             # print(book_title)
#             links = book_div.xpath('./div/ul/li/a')
#             for link in links:
#                 row = parse_row(book_title,link)
#                 if row:
#                     rows.append(row)
#     return rows
#
# def save_books(filename, books):
#     '''
#     将图书列表保存到CSV文件中
#     '''
#     # 构造表头
#     header = ('book_title', 'title', 'href', 'date')
#     # 存储为CSV文件
#     with open(filename, 'w') as f:
#         csv_writer = csv.writer(f,)
#         csv_writer.writerow(header)
#         csv_writer.writerows(books)

# %%
# 解析图书
books = bxp.parse_books(r.text)

# %%
# 保存图书
bxp.save_books('books.csv', books)

# %%
# 图书数据分析
import pandas as pd
df = pd.read_csv('books.csv')
df
# Out:
#      book_title                            title  \
# 0    盗墓笔记1七星鲁王宫                      七星鲁王 第一章 血尸
# 1    盗墓笔记1七星鲁王宫                    七星鲁王 第二章 五十年后
# 2    盗墓笔记1七星鲁王宫                     七星鲁王 第三章 瓜子庙
# 3    盗墓笔记1七星鲁王宫                      七星鲁王 第四章 尸洞
# 4    盗墓笔记1七星鲁王宫                      七星鲁王 第五章 水影
# 5    盗墓笔记1七星鲁王宫                     七星鲁王 第六章 积尸地
# 6    盗墓笔记1七星鲁王宫                  七星鲁王 第七章 一百多个人头
# 7    盗墓笔记1七星鲁王宫                      七星鲁王 第八章 山谷
# 8    盗墓笔记1七星鲁王宫                      七星鲁王 第九章 古墓
# 9    盗墓笔记1七星鲁王宫                      七星鲁王 第十章 影子
# 10   盗墓笔记1七星鲁王宫                    七星鲁王 第十一章 七星棺
# 11   盗墓笔记1七星鲁王宫                      七星鲁王 第十二章 门
# 12   盗墓笔记1七星鲁王宫               七星鲁王 第十三章 02200059
# 13   盗墓笔记1七星鲁王宫                    七星鲁王 第十四章 闷油瓶
# 14   盗墓笔记1七星鲁王宫                      七星鲁王 第十五章 屁
# 15   盗墓笔记1七星鲁王宫                     七星鲁王 第十六章 小手
# 16   盗墓笔记1七星鲁王宫                      七星鲁王 第十七章 洞
# 17   盗墓笔记1七星鲁王宫                     七星鲁王 第十八章 大树
# 18   盗墓笔记1七星鲁王宫                     七星鲁王 第十九章 女尸
# 19   盗墓笔记1七星鲁王宫                     七星鲁王 第二十章 钥匙
# 20   盗墓笔记1七星鲁王宫                  七星鲁王 第二十一章 青眼狐尸
# 21   盗墓笔记1七星鲁王宫                  七星鲁王 第二十二章 八重宝函
# 22   盗墓笔记1七星鲁王宫                    七星鲁王 第二十三章 棺椁
# 23   盗墓笔记1七星鲁王宫                    七星鲁王 第二十四章 活尸
# 24   盗墓笔记1七星鲁王宫                    七星鲁王 第二十五章 玉俑
# 25   盗墓笔记1七星鲁王宫                  七星鲁王 第二十六章 紫玉匣子
# 26   盗墓笔记1七星鲁王宫                    七星鲁王 第二十七章 谎言
# 27   盗墓笔记1七星鲁王宫                     七星鲁王 第二十八章 火
# 28   盗墓笔记1七星鲁王宫                   七星鲁王 第二十九章 紫金匣
# 29   盗墓笔记1七星鲁王宫                    怒海潜沙 第一章 蛇眉铜鱼
# ..          ...                              ...
# 250    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 传说
# 251    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 石灰
# 252    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 族谱
# 253    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 安氏
# 254    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 大雨
# 255    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 物体
# 256    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 死亡
# 257    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 目的
# 258    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 设局
# 259    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 猎物
# 260    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 真相
# 261    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 秘密
# 262    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 尾声
# 263    盗墓笔记 贺岁篇                      盗墓笔记 贺岁篇 后记
# 264    盗墓笔记 贺岁篇            《盗墓笔记》电视剧启动 吴秀波陈坤疑将参演
# 265    盗墓笔记 贺岁篇                 盗墓笔记电视剧来了！胡歌演男主角
# 266    盗墓笔记 贺岁篇        【最炫盗墓风】盗墓笔记X最炫民族风X爱杀宝贝ED.
# 267    盗墓笔记 贺岁篇                   《盗墓笔记》带你探寻云顶天宫
# 268    盗墓笔记 贺岁篇                     《盗墓笔记》电影版人物表
# 269    盗墓笔记 贺岁篇               《盗墓笔记》中真实存在的27件奇葩物
# 270    盗墓笔记 贺岁篇                       古代人的“盗墓笔记”
# 271    盗墓笔记 贺岁篇  《盗墓笔记》烂成渣http://seputu.com/秦岭神树
# 272    盗墓笔记 贺岁篇                     盗墓笔记（另类）.mp3
# 273      盗墓笔记重启                盗墓笔记重启  第一章 南京储物柜
# 274      盗墓笔记重启               盗墓笔记重启 ·第二章 废弃的气象站
# 275      盗墓笔记重启                 盗墓笔记重启 第三章 三叔的尸体
# 276      盗墓笔记重启                   盗墓笔记重启  第四章 雷声
# 277      盗墓笔记重启                   盗墓笔记重启 第五章 杨大广
# 278      盗墓笔记重启                   盗墓笔记重启 第六章 听雷者
# 279      盗墓笔记重启          盗墓笔记全集(周建龙版） （全集 共314集）
#
#                                              href                 date
# 0                  http://seputu.com/biji1/1.html     2012-5-19 3:3:52
# 1                  http://seputu.com/biji1/2.html     2012-5-19 3:5:22
# 2                  http://seputu.com/biji1/3.html     2012-5-19 3:6:15
# 3                  http://seputu.com/biji1/4.html    2012-5-19 3:30:57
# 4                  http://seputu.com/biji1/5.html    2012-5-19 4:52:12
# 5                  http://seputu.com/biji1/6.html    2012-5-19 4:53:14
# 6                  http://seputu.com/biji1/7.html   2012-5-22 14:42:52
# 7                  http://seputu.com/biji1/8.html   2012-5-22 14:43:24
# 8                  http://seputu.com/biji1/9.html    2012-5-22 14:44:0
# 9                 http://seputu.com/biji1/10.html   2012-5-22 14:44:35
# 10                http://seputu.com/biji1/11.html    2012-5-22 14:45:8
# 11                http://seputu.com/biji1/12.html   2012-5-22 14:45:44
# 12                http://seputu.com/biji1/13.html   2012-5-22 14:46:15
# 13                http://seputu.com/biji1/14.html   2012-5-22 14:47:26
# 14                http://seputu.com/biji1/15.html   2012-5-22 14:47:55
# 15                http://seputu.com/biji1/16.html   2012-5-22 14:48:32
# 16                http://seputu.com/biji1/17.html    2012-5-22 14:49:5
# 17                http://seputu.com/biji1/18.html   2012-5-22 14:49:59
# 18                http://seputu.com/biji1/19.html   2012-5-22 14:50:30
# 19                http://seputu.com/biji1/20.html   2012-5-22 14:50:52
# 20                http://seputu.com/biji1/21.html   2012-5-22 14:51:25
# 21                http://seputu.com/biji1/22.html    2012-5-22 14:52:4
# 22                http://seputu.com/biji1/23.html   2012-5-22 14:52:51
# 23                http://seputu.com/biji1/24.html   2012-5-22 14:54:31
# 24                http://seputu.com/biji1/25.html   2012-5-22 14:54:54
# 25                http://seputu.com/biji1/26.html   2012-5-22 14:55:47
# 26                http://seputu.com/biji1/27.html   2012-5-22 14:56:22
# 27                http://seputu.com/biji1/28.html   2012-5-22 14:56:49
# 28                http://seputu.com/biji1/29.html   2012-5-22 14:57:29
# 29                http://seputu.com/biji1/30.html    2012-5-22 14:58:3
# ..                                            ...                  ...
# 250              http://seputu.com/hesui/572.html    2012-5-23 21:6:11
# 251              http://seputu.com/hesui/573.html    2012-5-23 21:6:50
# 252              http://seputu.com/hesui/574.html    2012-5-23 21:7:29
# 253              http://seputu.com/hesui/575.html    2012-5-23 21:8:18
# 254              http://seputu.com/hesui/576.html    2012-5-23 21:9:35
# 255              http://seputu.com/hesui/577.html   2012-5-23 21:10:15
# 256              http://seputu.com/hesui/578.html   2012-5-23 21:11:56
# 257              http://seputu.com/hesui/579.html   2012-5-23 21:12:54
# 258              http://seputu.com/hesui/580.html   2012-5-23 21:13:46
# 259              http://seputu.com/hesui/581.html   2012-5-23 21:14:15
# 260              http://seputu.com/hesui/582.html   2012-5-23 21:14:42
# 261              http://seputu.com/hesui/583.html    2012-5-23 21:15:9
# 262              http://seputu.com/hesui/584.html   2012-5-23 21:15:35
# 263              http://seputu.com/hesui/585.html    2012-5-23 21:16:9
# 264              http://seputu.com/hesui/586.html   2013-8-31 18:49:42
# 265              http://seputu.com/hesui/587.html   2013-8-31 18:51:28
# 266              http://seputu.com/hesui/588.html   2013-8-31 18:54:42
# 267              http://seputu.com/hesui/589.html    2013-8-31 19:4:40
# 268              http://seputu.com/hesui/590.html   2013-8-31 19:10:18
# 269              http://seputu.com/hesui/990.html    2015-7-12 9:59:22
# 270              http://seputu.com/hesui/991.html   2015-7-12 12:34:54
# 271              http://seputu.com/hesui/992.html   2015-7-25 16:41:39
# 272              http://seputu.com/hesui/993.html   2015-12-31 18:26:5
# 273   http://seputu.com/daomubijichongqi/994.html  2017-12-12 17:33:49
# 274   http://seputu.com/daomubijichongqi/996.html  2017-12-12 19:12:59
# 275   http://seputu.com/daomubijichongqi/997.html  2017-12-12 19:14:39
# 276   http://seputu.com/daomubijichongqi/998.html   2017-12-12 19:16:8
# 277   http://seputu.com/daomubijichongqi/999.html  2017-12-14 15:53:37
# 278  http://seputu.com/daomubijichongqi/1000.html   2017-12-14 15:57:8
# 279  http://seputu.com/daomubijichongqi/1001.html    2018-5-6 14:23:57
#
# [280 rows x 4 columns]
